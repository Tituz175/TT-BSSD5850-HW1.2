# %% [markdown]
# # Homework 1.2

# %%
import numpy as np
from PIL import Image

# %% [markdown]
# ## Question 2

# %%
img = Image.open("question2.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1402x187>

# %% [markdown]
# #### Solution

# %%
matrixA = np.array([
    [3, 1],
    [4, 2]
])
matrixB = np.array([
    [2, 3],
    [1, 5]
])
matrixA.dot(matrixB)
# Out:
# array([[ 7, 14],
#        [10, 22]])

# %% [markdown]
# ## Question 7

# %%
img = Image.open("question7.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1622x262>

# %% [markdown]
# #### Solution

# %%
matrixA = np.array([
    [3, -1, 2],
    [-2, 4, 0]
])
matrixB = np.array([
    [2, 0],
    [-1, 4],
    [-3, 2]
])
matrixB.dot(matrixA)
# Out:
# array([[  6,  -2,   4],
#        [-11,  17,  -2],
#        [-13,  11,  -6]])

# %% [markdown]
# ## Question 12

# %%
img = Image.open("question12.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1797x262>

# %% [markdown]
# #### Solution

# %%
matrixA = np.array([
    [3, -2, 5],
    [0, -1, 6],
    [-4, 2, -1]
])
matrixB = np.array([
    [2, -1, 0],
    [3, -5, 2],
    [1, 4, -2]
])
matrixB.dot(matrixA)
# Out:
# array([[  6,  -3,   4],
#        [  1,   3, -17],
#        [ 11, -10,  31]])
